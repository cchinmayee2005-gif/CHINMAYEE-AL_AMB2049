# %%
crops=["rice","wheat","maize","pulses"]
fertilizer=["urea","DAP","NPK","compost"]
print("length",len(crops))
print("range",range(len(crops)))
# Out:
# length 4
# range range(0, 4)

# %%
for i in range(len(fertilizer)):
 print("crops needing fertilizers:"fertilizer)
# Out:
#   File "/tmp/ipython-input-1143137072.py", line 2
#     print("crops needing fertilizers:"fertilizer)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
