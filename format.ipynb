# %%
for  i in [10,20,300]:
   print(i)
# Out:
# 10
# 20
# 300

# %%
for i in [10,100,5]:
  print (i)
# Out:
# 10
# 100
# 5

# %%
a=10.5a=10
print(type(a))
# Out:
# <class 'float'>

# %%
a="h"
print(type(a))
# Out:
# <class 'str'>

# %%
a=8
print(type(a))
# Out:
# <class 'int'>

# %%
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
a=[10]
print(type(a))
# Out:
# <class 'list'>

# %%
a=(10)
print(type(a))
# Out:
# <class 'int'>

# %%
a(10,20,30)
print(type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3080466483.py in <cell line: 0>()
# ----> 1 a(10,20,30)
#       2 print(type(a))
#
# TypeError: 'int' object is not callable

# %%
a=(10,20)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=15
print("value of a is",a)
print(type(a))
# Out:
# value of a is 15
# <class 'int'>

# %%
a=30
print("value of a is ",a)
print(type(a))
# Out:
# value of a is  30
# <class 'int'>

# %%
a=10
b=20
print("value of a and b are",a,b)
# Out:
# value of a and b are 10 20

# %%
a=10
b=20
print("value of a and b are {}and {}".format(a,b))
# Out:
# value of a and b are 10and 20

# %%
a=10
b=20
print("value of a and b are {1} and {0}".format(a,b))
# Out:
# value of a and b are 20 and 10

# %%
a=10
b=20
print("value of b and a are {1} and {0}". format(a,b,))
# Out:
# value of b and a are 20 and 10

# %%
pi="pizza"
print("i love {2} {0} and  {1}". format("burger","pi","iceceream"))
# Out:
# i love iceceream burger and  pi

# %%
a=int(input("enter a number"))
print(a)
print(type(a))

# %%
a=b=int(input("4,5"))
print(a,b)
print(type(a))
