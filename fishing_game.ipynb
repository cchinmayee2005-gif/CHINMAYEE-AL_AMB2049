# %%
import random
random.randint(1,45)
# Out:
# 35

# %%
numbers=[1,2,3,4,5]
print(random.sample(numbers,3))
# Out:
# [4, 3, 5]

# %%
marks={"math":80,"english":75}
print(marks.get("math"))
# Out:
# 80

# %%
money=50
print("i have $",money)
print("i have ${0}".format(money))
print(f"i have ${money}")
# Out:
# i have $ 50
# i have $50
# i have $50

# %%
import random
inventory={}
total_money=0
fish_prices={"rohu":12,"catla":18,"sinchu":24}

print("\n fishing game menu")
print("1 catch the fish")
print("2 view inventory")
print("3 sell the fish")
print("4 exit")

while True:
  choice=int(input("choose an option:"))
  if choice==1:
    fish=random.choice(list(fish_prices.keys()))
    inventory[fish]=inventory.get(fish,0)+1
    print(f"you caught a {fish}!")
  elif choice==2:
    if inventory=={}:
      print("no fish")
    else:
      print("your inventory:")
      for fish,count in inventory.items():
        print(f"{fish}:{count}")
  elif choice==3:
    if inventory=={}:
      print("no fish to sell")
    else:
      earnings=0
      for fish ,count in inventory.items():
        earnings+=fish_prices[fish]*count
      total_money +=earnings
      inventory.clear()
      print(f"you sold all fish for${earnings}!")
  elif choice==4:
    print(f"final money earned:${total_money}")
    break
  else:
      print("invalid choice.try again")
# Out:
#  fishing game menu
# 1 catch the fish
# 2 view inventory
# 3 sell the fish
# 4 exit
# choose an option:1
# you caught a catla!
# choose an option:2
# your inventory:
# catla:1
# choose an option:3
# you sold all fish for$18!
# choose an option:4
# final money earned:$18

# %%
import math as m
print("exp(-200)  ;",m.exp(-200))
# Out:
# exp(-200)  ; 1.3838965267367376e-87

# %%
print("log(100,2)  ;",m.log(100,2))
# Out:
# log(100,2)  ; 6.643856189774725

# %%
print("log(100,10)  ;",m.log(100,10))
# Out:
# log(100,10)  ; 2.0

# %%
5print("log10(100);",m.log10(100))
# Out:
#   File "/tmp/ipython-input-1268648579.py", line 1
#     5print("log10(100);",m.log10(100))
#     ^
# SyntaxError: invalid decimal literal

# %%
print("mcos(30) ;",m.cos(30))
# Out:
# mcos(30) ; 0.15425144988758405

# %%
def sumfn(m,n):
  add=m+n
  print(add)
a=10
b=20
(sumfn(a,b))
# Out:
# 30

# %%
def sumfn(m,n):
  add=m+n
  return add
a=10
b=20
c=sumfn(a,b)
print(c)
# Out:
# 30

# %%
def sumfn():
  a=10
  b=20
add=a+b
print(add)
# Out:
# 30

# %%
def sumfn():
  a=10
  b=20
  add=a+b
  return add
print(sumfn())
# Out:
# 30
