# %%
import pandas as pd
import numpy as np

data=pd.DataFrame({
    "plot":["A","B","C","D","E"],
    "yield_kg":[2500,np.nan,2800,np.nan,2600],
    "rainfall":[150,200,np.nan,27,np.nan],
    "temperature":[28,30,29,np.nan,27]
})
print("==Data with missing values==")
print(data)
# Out:
# ==Data with missing values==
#   plot  yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0       NaN         29.0
# 3    D       NaN      27.0          NaN
# 4    E    2600.0       NaN         27.0

# %% [markdown]
# detecting missing data

# %%
print("\n==Detecting missing values==")
print("is null?")
print(data.isnull())
print(data.isnull().sum())
# Out:
# ==Detecting missing values==
# is null?
#     plot  yield_kg  rainfall  temperature
# 0  False     False     False        False
# 1  False      True     False        False
# 2  False     False      True        False
# 3  False      True     False         True
# 4  False     False      True        False
# plot           0
# yield_kg       2
# rainfall       2
# temperature    1
# dtype: int64

# %% [markdown]
# fillna  fill not a number fill with mean value

# %%
#fill with mean
data_mean=data.copy()
print(data_mean["yield_kg"])
data_mean["yield_kg"]=data_mean["yield_kg"].fillna(data_mean["yield_kg"].mean)
print("\n","fill wiyh mean:")
print(data_mean["yield_kg"])
# Out:
# 0    2500.0
# 1       NaN
# 2    2800.0
# 3       NaN
# 4    2600.0
# Name: yield_kg, dtype: float64
#
#  fill wiyh mean:
# 0                                               2500.0
# 1    <bound method Series.mean of 0    2500.0\n1   ...
# 2                                               2800.0
# 3    <bound method Series.mean of 0    2500.0\n1   ...
# 4                                               2600.0
# Name: yield_kg, dtype: object

# %%
#fill with median
data_median=data.copy()
print(data_median["rainfall"])
data_median["rainfall"]=data_median["rainfall"].fillna(data_median["rainfall"].median())
print(data_median["rainfall"])
# Out:
# 0    150.0
# 1    200.0
# 2      NaN
# 3     27.0
# 4      NaN
# Name: rainfall, dtype: float64
# 0    150.0
# 1    200.0
# 2    150.0
# 3     27.0
# 4    150.0
# Name: rainfall, dtype: float64

# %% [markdown]
# #ffill it replaces missing values(nan)

# %%
#forward fill(use previous value)
data_ffill=data.copy()
print(data_ffill)
data_ffill=data_ffill.fillna(method="ffill")
print("\n forward fill:")
print(data_ffill)
# Out:
#   plot  yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0       NaN         29.0
# 3    D       NaN      27.0          NaN
# 4    E    2600.0       NaN         27.0
#
#  forward fill:
#   plot  yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# 1    B    2500.0     200.0         30.0
# 2    C    2800.0     200.0         29.0
# 3    D    2800.0      27.0         29.0
# 4    E    2600.0      27.0         27.0
# /tmp/ipython-input-2469094972.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_ffill=data_ffill.fillna(method="ffill")

# %%
#==dropping missing data
print("\n==droping rows==")
data_dropped=data.dropna()
print(data_dropped)
print(f"original rows:{len(data)},After drop:{len(data_dropped)}")
# Out:
# ==droping rows==
#   plot  yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         28.0
# original rows:5,After drop:1
