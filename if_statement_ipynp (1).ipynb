# %%
if 10>5:
  print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
if 11>9:
  print("11 is greater than 9")
# Out:
# 11 is greater than 9

# %%
a=12
b=14
if a>b:
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
age=18
a=10
b=20
if age>a,b:
  print("a is eligible to vote")
else:
  print("b is eligible to vote")
# Out:
# b is eligible to vote

# %%
age=18
a=18
b=14
if age>=b:
  print("a is eligible to vote")
else:
  print("b is eligible to vote")
# Out:
# a is eligible to vote

# %%
age=18
a=36
b=18
if age>=b:
  print ("a is eligible to vote")
else:
  print("b is eligible to vote")
# Out:
# a is eligible to vote

# %%
age=20
if age>18:
  print("a is eligible")
else:
  print("a is not eligible")
# Out:
# a is eligible

# %%
num=0
if num==0:
  print("num is zero")
elif(num<0):
  print("num is negative")
else:
  print("num is positive")
# Out:
# num is zero

# %%
n=2
if n>9:
  print("grade A")
elif(n>=7 and n<9):
  print("grade B")
elif(n>=5 and n<7):
  print("grade C")
else:
  print("fail")
# Out:
# fail

# %%
n=3
if n%2==0:
  print("n is even")
else:
  print("n is odd")
# Out:
# n is odd

# %%
n=2
if n%2==0:
  print("n is even")
else:
  print("n is odd")
# Out:
# n is even

# %%
for i in range(1,10):
  print (i)
