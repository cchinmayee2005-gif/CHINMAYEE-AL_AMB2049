# %%
print(x)
for i in x:
  print("value of i",i,"after adding 2 is",i+2)
  print("value of {},adding 2 is {}".format(i,i+2))
# Out:
# [10, 20, 30]
# value of i 10 after adding 2 is 12
# value of 10,adding 2 is 12
# value of i 20 after adding 2 is 22
# value of 20,adding 2 is 22
# value of i 30 after adding 2 is 32
# value of 30,adding 2 is 32

# %%
x=[10,11,13,14]
if 12 not in x:
  print("mark absent for 12")
if 11 in x:
  print("mark present foR 11")
  print("end")
# Out:
# mark absent for 12
# mark present foR 11
# end

# %%
crops=["rice","wheat","maize"]
print("crops grown in field")
for i in crops:
  print (i)

for i in crops:
  print("crop is i",i)
x.append("sugarcane")
print (crops)
# Out:
# crops grown in field
# rice
# wheat
# maize
# crop is i rice
# crop is i wheat
# crop is i maize
# ['rice', 'wheat', 'maize']

# %%
crops=["rice","wheat","maize"]
for i in x:
  print ("crop is,",i)
x.append("sugarcane")
print(crops)
# Out:
# Streaming output truncated to the last 5000 lines.
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# crop is, sugarcane
# ...

# %%
crops.remove("wheat")
print(crops)
# Out:
# ['rice', 'maize']

# %%
crops.append("sugarcane")
print(crops)
# Out:
# ['rice', 'maize', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane']

# %%
crops.insert(1,"sugarcane")
print("after inserting sugarcane")
print(crops)
# Out:
# after inserting sugarcane
# ['rice', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane']

# %%
crops.count("sugarcane")
print("count of sugarcane is",crops.count("sugarcane"))
print(crops)
# Out:
# count of sugarcane is 5
# ['rice', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane', 'sugarcane']

# %%
crops.pop()
print(crops)
# Out:
# ['rice', 'sugarcane', 'sugarcane', 'sugarcane']

# %%
crops.pop()
print(crops)
# Out:
# ['rice', 'sugarcane']

# %%
crops.insert("wheat")
print("the iserting crop is")
print(crops)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-106211413.py in <cell line: 0>()
# ----> 1 crops.insert("wheat")
#       2 print("the iserting crop is")
#       3 print(crops)
#
# TypeError: insert expected 2 arguments, got 1
