# %%
def max(num1,num2):
  if num1>num2:
    result=num1
  else:
    result=num2
  return result

x=100
y=300
z=max(x,y)
print(z)
# Out:
# 300

# %%
factorial=1
num=int(input("enter a input"))
for i in range(1,num + 1):
  factorial *=i
  print("the factorial",factorial)
# Out:
# enter a input10
# the factorial 1
# the factorial 2
# the factorial 6
# the factorial 24
# the factorial 120
# the factorial 720
# the factorial 5040
# the factorial 40320
# the factorial 362880
# the factorial 3628800

# %% [markdown]
# # with parameter,without return type
# # outsie function read the input,print output inside the function

# %%
=1

# %%
def fact(m):
  fact=1
  if(m>0):
     for i in range(1,m+1):
       fact=fact*i
     print("factorial of",m,"is",fact)
  else:
     print("enter the valid number")

n=int(input("enter a number:"))
fact(n)
# Out:
# enter a number:10
# factorial of 10 is 3628800

# %% [markdown]
# # with parameter  with return type

# %%
def fact(m):
  fact=1
  if(m>0):
     for i in range(1,m+1):
       fact=fact*i
     return fact
  else:
     print("enter the valid number")

n=int(input("enter a number:"))
z=fact(n)
print(z)
# Out:
# enter a number:10
# 3628800

# %%
def fact():
  m=int(input("enter a number:"))
  fact=1
  if(m>0):
     for i in range(1,m+1):
       fact=fact*i
     print("factorial of",m,"is",fact)
  else:
     print("enter the valid number")

fact()
# Out:
# enter a number:10
# factorial of 10 is 3628800
