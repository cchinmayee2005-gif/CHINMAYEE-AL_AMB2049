# %%
names=['lakshmi','shwetha','rama']
age=[20,23,22]
for i in range(len(names)):
  print(names[i],"age is",age[i])
# Out:
# lakshmi age is 20
# shwetha age is 23
# rama age is 22

# %%
for n,a in zip(names,age):
 print(n,"age is",a)
# Out:
# lakshmi age is 20
# shwetha age is 23
# rama age is 22

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need=[300,200,100,150,80]
print ("length",len(crops))
# Out:
# length 5

# %%
print("range",range(len(crops)))
# Out:
# range range(0, 5)

# %%
print("crop and water requirement:")
for i in range(len(crops)):
 print(crops[i],"_",water_need[i],"mm")
# Out:
# crop and water requirement:
# rice _ 300 mm
# wheat _ 200 mm
# millet _ 100 mm
# maize _ 150 mm
# pulses _ 80 mm

# %%
print("crops needing high water(>180mm):")
for i in range(len(water_need)):
  if water_need[i]>180:
    print(crops[i])
# Out:
# crops needing high water(>180mm):
# rice
# wheat

# %%
crops=["rice","wheat","maize","pulses"]
yield_tons=[3.5,4.0,2.8,1.5]
average_yield=sum(yield_tons)/len(yield_tons)
print("average rop yield:",average_yield,"tons/hectare")
# Out:
# average rop yield: 2.95 tons/hectare

# %%
crops=["rice","wheat","maize"]
water_need=[200,300,400]
max_water=max(water_need)
index=water_need.index(max_water)
print("crop with highest water requirement:",crops[index])
# Out:
# crop with highest water requirement: maize

# %%
max_crop=max(zip(water_need,crops))
print(max_crop)
print("crop with highest water requirement:",max_crop[1])
# Out:
# (400, 'maize')
# crop with highest water requirement: maize

# %%
list1=[200,300,400]
max(list1)
# Out:
# 400

# %%
crop=("maize","rice","wheat")
maxyield=(10,20,30,)
max(crop)
print("max crop yield:",max(maxyield))
# Out:
# max crop yield: 30

# %%
crop=("rice","wheat","maize","cowpea")
fertilizer=("urea","DAP","NPK","compost")
print("length",(len(crops)))
print("range",range(len(crops)))
# Out:
# length 3
# range range(0, 3)
