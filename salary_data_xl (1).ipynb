# %%
import pandas as pd
df=pd.read_csv("/Salary_Data-1.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
import pandas as pd
df=pd.read_csv("/Salary_Data-1.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %% [markdown]
# from os import error
# from inspect import modulesbyfile
# from typing import Optional
# from typing_extensions import dataclass_transform
# #impoerting the package
# read the dataset
#
# slicing the data set as independent and dependent variable
#
# optional pre processing
#
# handling the missing dataclass_transformidentify outliers
#
# spliting the data swet into training and testing and another pre processing
#
# step standardization is Optionalcreating an objectof algorith
#
# train the modules
#
# predict the model
#
# calculate intercept and coefficient
#
# evaluation metrics
# for regression =finding different pd.errors
# finding accuracy ,precision,
# mean absolute errors
# mean square root error
# # visualisation ***bold text***

# %%
x=df.iloc[:,0].values
y=df.iloc[:,-1].values
print(x)
print(y)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=1/3,random_state=0)
print(df.shape)
# Out:
# (30, 2)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df=pd.read_csv("/Salary_Data-1.csv")
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
print(df.head(5))
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
x=df.iloc[:,0].values
y=df.iloc[:,-1].values
print(x)
print(y)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)
print(df.shape)
# Out:
# (30, 2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20,)
# (10,)
# (20,)
# (10,)

# %%
import numpy as np
x_mean=np.mean(x_train)
y_mean=np.mean(y_train)
print(x_mean,y_mean)
# Out:
# 4.7299999999999995 71022.5

# %%
n=len(x_train)
num,den=0,0

for i in range(n):
  num+=(x_train[i]-x_mean)*(y_train[i]-y_mean)
  den+=(x_train[i]-x_mean)**2

b1=num/den
b0=y_mean-(b1*x_mean)
print("b0",b0)
# Out:
# b0 26816.19224403117

# %%
y_pred_code=b0+b1*x_test
print(y_pred_code)
# Out:
# [ 40835.10590871 123079.39940819  65134.55626083  63265.36777221
#  115602.64545369 108125.8914992  116537.23969801  64199.96201652
#   76349.68719258 100649.1375447 ]

# %%
print(y_test)
# Out:
# [ 37731 122391  57081  63218 116969 109431 112635  55794  83088 101302]

# %%
#mean square error
n1=len(y_test)
mse=0
for i in range(n1):
  mse+=(y_test[i]-y_pred_code[i])**2

mse=mse/n1
print(mse)
# Out:
# 21026037.329511303

# %%
#root mean square error
rmse=np.sqrt(mse)
print(rmse)
# Out:
# 4585.415720467589

# %% [markdown]
# # Machine learning algorithm

# %%
from sklearn import metrics
import numpy as np
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred_code))
print("mean squared error :",metrics.mean_squared_error(y_test,y_pred_code))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred_code)))
# Out:
# mean absolute error: 3426.426937430709
# mean squared error : 21026037.329511303
# root mean squared error: 4585.415720467589

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,b0 + b1 * x_train,color="blue")
plt.title("salary vs experience-training set")
plt.xlabel("year of experience")
plt.ylabel("salary")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,b0 + b1 * x_train,color="blue")
plt.title("salary vs experience-training set and actual values of y_test")
plt.xlabel("year of experience")
plt.ylabel("salary")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test,y_pred_code,color="red")
plt.plot(x_train,b0 + b1 * x_train,color="blue")
plt.title("salary vs experience-training set")
plt.xlabel("year of experience")
plt.ylabel("salary")

plt.show()
