# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
if(a>b):
  print("{} is greater between{}and{}".format(a,a,b))
elif(b>a):
  print("{}is greater between {}and{}".format(b,a,b))
else:
  print("{}and{} are equal".format(a,b))
# Out:
# enter a number0
# enter a number-2
# 0 is greater between0and-2

# %%
r=int(input("enter a radius of circle"))
ch=int(input("enter your choice\n1.area\n2.perimeter"))
area=3.14*r*r
perimeter=2*3.14*r
if(ch==1):
  print("area of circle is area",area)
elif(ch==2):
  print("perimeter of circle",perimeter)
else:
  print("error")
# Out:
# enter a radius of circle4
# enter your choice
# 1.area
# 2.perimeter2
# perimeter of circle 25.12

# %%
List1=[1,2,3,4,"hi",5]
print(List1)
# Out:
# [1, 2, 3, 4, 'hi', 5]

# %%
print(len(List1))
# Out:
# 6

# %%
print(List1.index(3))
List1.append("hello")
print(List1)
print(List1.count("hi"))
List1.insert(3,"GM")
# Out:
# 2
# [1, 2, 3, 'GM', 4, 'hi', 5, 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello']
# 1

# %%
List1.reverse()
print(List1)
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 5, 'hi', 4, 'GM', 'GM', 3, 2, 1]

# %%
print(List1.pop(3))
print(List1)
# Out:
# 4
# ['hello', 'hello', 'hello', 'GM']

# %%
List1.pop(4)
print(List1)
# Out:
# ['hello', 'hello', 'hello', 'hello', 4, 'GM']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-704784240.py in <cell line: 0>()
# ----> 1 List1.remove(" all hello")
#       2 print(List1)
#
# ValueError: list.remove(x): x not in list

# %%
List1.clear()
print(List1)
# Out:
# []

# %%
[2,5,6]
del(List1)
print(List)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
List1=[2,3,4,7,8,6,1,0,5]
print(List1)
List1.sort()
print(List1)
print(max(List1))
print(min(List1))
# Out:
# [2, 3, 4, 7, 8, 6, 1, 0, 5]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# 8
# 0

# %%
List2=['a','h','H',"A"]
List2.sort()
print(List2)
List3=["Java","javascript"]
List.sort()
print(List3)
# Out:
# ['A', 'H', 'a', 'h']
# ['Java', 'javascript']

# %%
a=[2,3,5]
b=a
print("a",b)
print("b",b)
b.insert(9,8)
print("a:",a)
print("b:",b)
# Out:
# a [2, 3, 5]
# b [2, 3, 5]
# a: [2, 3, 5, 8]
# b: [2, 3, 5, 8]
