# %%
if 10>5:
    print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
if 25<7:
   print("25 is lesser than 7")

# %%
a=30
b=20
if a>b:
 print ("a is greater than b")
# Out:
# a is greater than b

# %%
a=50
b=65
if a>b:
  print("a is greater than b")
else:
   print ("a is lesser than b")
# Out:
# a is lesser than b

# %%
a=70
b=30
if a<b:
  print ("a is lesser than b")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
age=33
if age>18:
  print ("yes")
  print("person is eligible for vote")
else:
  print("no")
  Print("person is not eligible for vote")
# Out:
# yes
# person is eligible for vote

# %%
p=17
if p>18:
  print("yes")
  print ("person is eligible for vote")
else:
  print("no")
  print("person is not eligible for vote")
# Out:
# no
# person is not eligible for vote

# %%
M=20
if M>35:
  print("yes")
  print("person is pass")
else:
  print("n0")
  print("person is fail")
# Out:
# n0
# person is fail

# %%
N=10
if N>0:
  print ("N is positive")
elif N<0:
  print("N is negative")
else:
 print("N is equal to zero")
# Out:
# N is positive

# %%
G=9.5
if G>9:
 print("person got a A grade")
elif G>7 and G<9:
  print("person got a B grade")
elif G>5 and G<7:
  print("person got a C grade")
else:
  print("person is failed")
# Out:
# person got a A grade

# %%
A=8
if A%2==0:
  print("A is even")
else:
  print("A is odd")
# Out:
# A is even

# %%
Num=11
if Num%2==0:
  print("Num is even")
else:
  print("Num is odd")
# Out:
# Num is odd
