# %%
file=open("gkvk.txt","w")
file.write("good morning")
file.close()

# %%
file=open("gkvk.txt","r")
content=file.readlines()
print(content)
file.close()
# Out:
# ['good morning\n', ' this append text\n', ' this append text\n', ' this append text']

# %%
file=open("gkvk.txt","a")
file.write("\n this append text")
file.close()

# %%
with open("gkvk.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# good morning
#  this append text
#  this append text
#  this append text

# %%
with open("gkvk.txt","r") as file:
  print(file.readline())
# Out:
# good morning

# %%
with open ("gkvk.txt","r")as file:
  print(file.readlines())
# Out:
# ['good morning\n', ' this append text\n', ' this append text\n', ' this append text']

# %%
try:
  file=open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("file not found")
# Out:
# file not found

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def expr(a,b):
  c=a/b
  print(c)
a=8
b=2
expr(a,b)
# Out:
# 4.0

# %%
def expr(a,b):
  c=a/b
  print(c)
a=5
b=0
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-3737519492.py in <cell line: 0>()
#       4 a=5
#       5 b=0
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-3737519492.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/b
#       3   print(c)
#       4 a=5
#       5 b=0
#
# ZeroDivisionError: division by zero

# %%
def expr(a,b):
  c=a/f
  print(c)
a=4
b=2
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1972001941.py in <cell line: 0>()
#       4 a=4
#       5 b=2
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-1972001941.py in expr(a, b)
#       1 def expr(a,b):
# ----> 2   c=a/f
#       3   print(c)
#       4 a=4
#       5 b=2
#
# NameError: name 'f' is not defined

# %%
def expr(a,b):
  try:
    c=a/f
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not declared")
  except:
    print("some error is occured")
  else:
    print("executed without errors")
    print("value of c",c)
  finally:print("end of the program")
a=4
b=2
expr(a,b)
# Out:
# variable not declared
# end of the program
