# %%
dict={"rice":120,"wheat":85,"maize":60}
print(dict)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60}

# %%
for i in range(len(dict)):
     print("tatal number of crops cultivated by farmer;",len(dict))
# Out:
# tatal number of crops cultivated by farmer; 3
# tatal number of crops cultivated by farmer; 3
# tatal number of crops cultivated by farmer; 3

# %%
keylist=list(dict.keys())
print(keylist)
# Out:
# ['rice', 'wheat', 'maize']

# %%
vallist=list(dict.values())
print(vallist)
# Out:
# [120, 85, 60]

# %%
print("yield of",keylist[1],"is",vallist[1])
# Out:
# yield of wheat is 85

# %%
print("yeild of wheat is",dict.get("wheat"))
# Out:
# yeild of wheat is 85

# %%
dict2={"rice":130}
dict.update(dict2)
print("dict;",dict)
# Out:
# dict; {'rice': 130, 'wheat': 85, 'maize': 60, 45: 45, 'pulse': 45}

# %%
print(dict.keys())
# Out:
# dict_keys(['rice', 'wheat', 'maize', 45, 'pulse'])

# %%
print(dict.values())
# Out:
# dict_values([130, 85, 60, 45, 45])

# %%
print("is sugarcane;","sugarcane" in dict.keys())
# Out:
# is sugarcane; False

# %%
print("increas yield of wheat by 1o is;",dict["wheat"]+10)
# Out:
# increas yield of wheat by 1o is; 95

# %%
print("total yield of all crops is;",sum(dict.values()))
# Out:
# total yield of all crops is; 365

# %%
keylist=["rice","wheat","maize","pulse"]
vallist=[120,95,60,45]
mdict = {}
mdict["rice"]=120
mdict["wheat"]=95
mdict["maize"]=60
mdict["pulse"]=45
print(mdict)
# Out:
# {'rice': 120, 'wheat': 95, 'maize': 60, 'pulse': 45}

# %%
mdict = {}
for i in range(len(keylist)):
    mdict[keylist[i]] = vallist[i]
print(mdict)
# Out:
# {'rice': 120, 'wheat': 95, 'maize': 60, 'pulse': 45}

# %%
print("jowar yeild;", dict2.get("jowar"))
# Out:
# jowar yeild; None

# %%
dict.pop("rice")
print(dict)
# Out:
# {'wheat': 85, 45: 45}

# %%
dict.clear()
print(dict)
# Out:
# {}

# %%
T=("pratham","sharma",3.14,3)
print("T    ;",T)
print("number of elements;",len(T))
print("type of object ;",type(T))
# Out:
# T    ; ('pratham', 'sharma', 3.14, 3)
# number of elements; 4
# type of object ; <class 'tuple'>

# %%
T=("pratham","sharma",3.14,3)
print("T    ;",T)
i=0
print(" ")
while i<len(T):
  print(T[i])
  i+=1
# Out:
# T    ; ('pratham', 'sharma', 3.14, 3)
#
# pratham
# sharma
# 3.14
# 3

# %%
T=("pratham","sharma",3.14,3)
print("T    ;",T)
print("")
for i in range(len(T)):
  print(T[i])
# Out:
# T    ; ('pratham', 'sharma', 3.14, 3)
#
# pratham
# sharma
# 3.14
# 3

# %%
T=("pratham","sharma",3.14,3)
print("T    ;",T)
print("")
for s in T:
  print(s)
# Out:
# T    ; ('pratham', 'sharma', 3.14, 3)
#
# pratham
# sharma
# 3.14
# 3
