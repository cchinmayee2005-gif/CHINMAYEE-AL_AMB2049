# %%
T=(3,6,9,12,5,3,2)
print("T ",T)
print("T[1] ",T[1])
print("T[2] ",T[2])
print("T[-1]",T[-1])
# Out:
# T  (3, 6, 9, 12, 5, 3, 2)
# T[1]  6
# T[2]  9
# T[-1] 2

# %%
print("T[1:3]  ",T[1:3])
print("T[2:]   ",T[2:])
print("T[2:5]  ",T[2:5])
# Out:
# T[1:3]   (6, 9)
# T[2:]    (9, 12, 5, 3, 2)
# T[2:5]   (9, 12, 5)

# %%
print("T[-3:-5]  ",T[-3:-5])
# Out:
# T[-3:-5]   ()

# %%
T[::1]
# Out:
# (3, 6, 9, 12, 5, 3, 2)

# %%
T[::-1]
# Out:
# (2, 3, 5, 12, 9, 6, 3)

# %%
T[2]=900
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3195149640.py in <cell line: 0>()
# ----> 1 T[2]=900
#
# TypeError: 'tuple' object does not support item assignment

# %%
T.append(9.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1956851245.py in <cell line: 0>()
# ----> 1 T.append(9.8)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
T.insert(2,"rahul")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-678600356.py in <cell line: 0>()
# ----> 1 T.insert(2,"rahul")
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
T.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3994643415.py in <cell line: 0>()
# ----> 1 T.add(6)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
delT[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3267587595.py in <cell line: 0>()
# ----> 1 delT[2]
#
# NameError: name 'delT' is not defined

# %%
T.extend(9.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4279994569.py in <cell line: 0>()
# ----> 1 T.extend(9.8)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
T=("pratham","sharma",3.14,3)
print("T     ",T)
T1=list(T)
T1.append(9.8)
T=tuple(T1)

print(" ")
print("After add ",T)
# Out:
# T      ('pratham', 'sharma', 3.14, 3)
#
# After add  ('pratham', 'sharma', 3.14, 3, 9.8)

# %%
T1=list(T)

del T1[1]
T=tuple(T1)
print(" ")
print("after delete ",T)
# Out:
#
# after delete  ('pratham', 9.8)

# %%
T=(3,6,9,12,5,3,2)
print("T  ",T)
print("sum ",sum(T))
print("average ",sum(T)/len(T))
print("average ",sum(T)//len(T))
# Out:
# T   (3, 6, 9, 12, 5, 3, 2)
# sum  40
# average  5.714285714285714
# average  5

# %%
print("T  ",T)
print("max ",max(T))
print("min ",min(T))
# Out:
# T   (3, 6, 9, 12, 5, 3, 2)
# max  12
# min  2

# %%
print(5 in T)
# Out:
# True

# %%
T1=(2,3,5,7)
T2=(9,0,8,2)
T3=T1+T2
print("T3",T3)
# Out:
# T3 (2, 3, 5, 7, 9, 0, 8, 2)

# %%
T3=T1[1:2]+T2[1:3]
print("T3 ",T3)
# Out:
# T3  (3, 0, 8)

# %%
print("")
print("index of 9 in T ",T.index(9))
# Out:
# index of 9 in T  2

# %%
print("index of 7 in T",T.index(7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4135626308.py in <cell line: 0>()
# ----> 1 print("index of 7 in T",T.index(7))
#
# ValueError: tuple.index(x): x not in tuple

# %%
T1.count(3)
# Out:
# 1

# %%
l1=[1,2,3]
print(id(11))
l1.append(4)
print(id(l1))
# Out:
# 11654696
# 139502113928384

# %%
s1={1,2,3}
print(id(11))
s1.add(4)
print(id(11))
# Out:
# 11654696
# 11654696

# %%
d1={1:4,2:9,3:16}
print(id(11))
d1[3]=27
print(id(11))
# Out:
# 11654696
# 11654696

# %%
a="gkvk"
print(id(a))

a=a+"us"
print(id(a))
# Out:
# 139502113891328
# 139502113244960

# %%
s="python"
s[0]='j'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3976968061.py in <cell line: 0>()
#       1 s="python"
# ----> 2 s[0]='j'
#
# TypeError: 'str' object does not support item assignment

# %%
x=10
y=x
print(id(x))
print(id(y))

x=x+20
print(id(x))
print(id(y))
# Out:
# 11654664
# 11654664
# 11655304
# 11654664
