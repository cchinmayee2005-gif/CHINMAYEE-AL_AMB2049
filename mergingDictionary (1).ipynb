# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(cgpa)
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}

# %%
print("len(cgpa)=",len(cgpa))
# Out:
# len(cgpa)= 5

# %%
print(type(cgpa))
# Out:
# <class 'dict'>

# %%
print("cgpa of 1",cgpa[1])
# Out:
# cgpa of 1 8.9

# %%
print("cgpa of 4",cgpa[4])
# Out:
# cgpa of 4 6.7

# %%
print("cgpa of 7",cgpa[7])
# Out:
# cgpa of 7 9.1

# %%
print("cgpa of 3",cgpa[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4089032510.py in <cell line: 0>()
# ----> 1 print("cgpa of 3",cgpa[3])
#
# KeyError: 3

# %%
for k in cgpa:
    print("cgpa of",k,";\n",(cgpa[k]))
# Out:
# cgpa of 1 ;
#  8.9
# cgpa of 2 ;
#  5.6
# cgpa of 4 ;
#  6.7
# cgpa of 7 ;
#  9.1
# cgpa of 8 ;
#  5.3

# %%
for k in cgpa:
      print("cgpa of",k,";\\n",cgpa[k])
# Out:
# cgpa of 1 ;\n 8.9
# cgpa of 2 ;\n 5.6
# cgpa of 4 ;\n 6.7
# cgpa of 7 ;\n 9.1
# cgpa of 8 ;\n 5.3

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(cgpa)
print("\nkeys;",cgpa.keys())
print("\nvalues;",cgpa.values())
print(list(cgpa.items()))
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
# keys; dict_keys([1, 2, 4, 7, 8])
#
# values; dict_values([8.9, 5.6, 6.7, 9.1, 5.3])
# [(1, 8.9), (2, 5.6), (4, 6.7), (7, 9.1), (8, 5.3)]

# %%
cgpa[6]=7.9
print(cgpa)
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 6: 7.9}

# %%
cgpa[6]=7.9
print(cgpa)
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 6: 7.9}

# %%
del cgpa
print(cgpa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3863329136.py in <cell line: 0>()
# ----> 1 del cgpa
#       2 print(cgpa)
#
# NameError: name 'cgpa' is not defined

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
cgpa.clear()
print(cgpa)
# Out:
# {}

# %%
cgpa={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
s=0
for i in cgpa:
    s=s+cgpa[i]
print("\n sum",s)
print("average;",s/len(cgpa))
print("average;",s//len(cgpa))
# Out:
#  sum 35.599999999999994
# average; 7.119999999999999
# average; 7.0

# %%
min(cgpa.values())
# Out:
# 5.3

# %%
max(cgpa.values())
# Out:
# 9.1

# %%
keylist=list(cgpa.keys())
vallist=list(cgpa.values())
maxval=max(cgpa.values())
print("\nvalue=",maxval,"key;",keylist[vallist.index(maxval)])
# Out:
# value= 9.1 key; 7

# %%
print("\nkey having minvalue;",min(cgpa,key=cgpa.get))
print("key having maxvalue;",max(cgpa,key=cgpa.get))
# Out:
# key having minvalue; 8
# key having maxvalue; 7

# %%
print("Is key 2 present;",2 not in cgpa.keys())
print("Is key 9 present;",9 in cgpa.keys())
# Out:
# Is key 2 present; False
# Is key 9 present; False

# %%
cgpa={1:8.9,2:5.6,4:9.7}
cgpa1={4:6.7,7:9.1,8:5.3}
cgpa1.update(cgpa)
print("cgpa      ;",cgpa)
print("cgpa1     ;",cgpa1)
# Out:
# cgpa      ; {1: 8.9, 2: 5.6, 4: 9.7}
# cgpa1     ; {4: 9.7, 7: 9.1, 8: 5.3, 1: 8.9, 2: 5.6}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print(cars)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
print("dictionary;",cars)
# Out:
# dictionary; {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
cars2={"colour":"red"}
cars2.update(cars)
print("cars;",cars)
print("cars2;",cars2)
# Out:
# cars; {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# cars2; {'colour': 'red', 'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
print(cars.keys())
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
print(cars.values())
# Out:
# dict_values(['ford', 'mustang', 1964])

# %%
print(cars.items())
# Out:
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])

# %%
print("Is key model present;","model" in cars.keys())
# Out:
# Is key model present; True

# %%
keys=["movie","hero","release year"]
values=["kantara","rishab",2022]
mdict = {}
for i in range(len(keys)):
  mdict[keys[i]]=values[i]
print(mdict)
# Out:
# {'movie': 'kantara', 'hero': 'rishab', 'release year': 2022}

# %%
mdict["movie"]="kantara"
mdict["hero"]="rishab"
mdict["release date"]=2022
print(mdict)
# Out:
# {'movie': 'kantara', 'hero': 'rishab', 'release year': 2022, 'release date': 2022}

# %%
my_dict = {"name":"john", 10:[2,4,3]}
dict2 = my_dict.copy()
print(my_dict)
print(dict2)
print()
print("after doing change")
print()
my_dict.pop("name")
print(my_dict)
print(dict2)
print("change in my_dict will not reflect in dict2 (for top-level changes)")
# Out:
# {'name': 'john', 10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
#
# after doing change
#
# {10: [2, 4, 3]}
# {'name': 'john', 10: [2, 4, 3]}
# change in my_dict will not reflect in dict2 (for top-level changes)
